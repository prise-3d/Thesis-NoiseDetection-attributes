# %%
from rawls.rawls import RawlsSamples
import matplotlib.pyplot as plt

# %%
image_path = "/home/jbuisine/Documents/Thesis/Development/scenes-manager/renderers/PrISE-3D-pbrt-v4/build/samplesCoord/p3d_kitchen-view0/p3d_kitchen-view0-S1-000000.rawls"

# %%
rawls_image = RawlsSamples.load(image_path)

# %%
rawls_image.samples.shape
# Out:
# (1080, 1920, 2)

# %%
rawls_image_reshape = rawls_image.samples.reshape((1080 * 1920, 2))

# %%
rawls_image_reshape = rawls_image.samples[0:300, 0:300, :].reshape((300 * 300, 2))
x = rawls_image_reshape[:, 0]
y = rawls_image_reshape[:, 1]

# %%
fig= plt.figure(figsize=(40,30))
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.scatter(x, y)
